# %%
# 2.1 Biểu đồ phân bố của AQI
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('Du_lieu_Hanoi_Cleaned.csv')  
print(df.head())
plt.figure(figsize=(10, 5))
sns.histplot(df['aqi'], bins=30, kde=True, color='coral')
plt.title('Phân bố Chỉ số chất lượng không khí (AQI) tại Hà Nội')
plt.xlabel('AQI')
plt.ylabel('Tần suất')
plt.show()
# Out:
#                           timestamp    city  aqi  wind_speed  humidity  \
# 0  2025-01-20 22:53:00.802887+07:00  Hà Nội  237        13.7      47.0
# 1  2025-01-20 23:00:33.773883+07:00  Hà Nội  237        13.7      47.0
# 2  2025-01-20 23:03:37.661401+07:00  Hà Nội  237        13.7      47.0
# 3  2025-01-20 23:11:20.857578+07:00  Hà Nội  235        11.6      49.0
# 4  2025-01-21 03:03:26.115976+07:00  Hà Nội  256         9.2      55.0
#
#          date  hour  month          weather
# 0  2025-01-20    22      1  Night Clear Sky
# 1  2025-01-20    23      1  Night Clear Sky
# 2  2025-01-20    23      1  Night Clear Sky
# 3  2025-01-20    23      1  Night Clear Sky
# 4  2025-01-21     3      1  Night Clear Sky

# %%
# 2.2 Đánh giá mức độ ô nhiễm theo khung giờ trong ngày
plt.figure(figsize=(12, 6))
sns.boxplot(x='hour', y='aqi', data=df, palette='coolwarm')
plt.title('Mức độ ô nhiễm AQI theo từng khung giờ trong ngày')
plt.xlabel('Giờ trong ngày')
plt.ylabel('AQI')
plt.show()
# Out:
# C:\Users\huuso\AppData\Local\Temp\ipykernel_23452\2291548495.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='hour', y='aqi', data=df, palette='coolwarm')

# %%
# 2.3 Ma trận tương quan giữa các biến số số học
plt.figure(figsize=(8, 6))
correlation_matrix = df[['aqi', 'wind_speed', 'humidity', 'hour', 'month']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu_r', fmt='.2f', vmin=-1, vmax=1)
plt.title('Ma trận tương quan giữa các biến số')
plt.show()
